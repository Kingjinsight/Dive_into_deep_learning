# %% [markdown]
# 1. n元语法通过截断相关性，为处理长序列提供了一种实用的模型
# 2. 长序列存在的问题：他们很少出现或者不出现
# 3. 齐普夫定律支配着单词的分布，这个分布不仅适用于一元语法，还适用于其他n元语法
# 4. 通过拉普拉斯平滑法可以有效地处理结构丰富而频率不足的低频词词组
# 5. 读取长序列的主要方式是随机抽检欧阳和顺序分区。在迭代过程中，后者可以保证来自两个相邻的小批量中的子序列在原始序列中也是相邻的。
